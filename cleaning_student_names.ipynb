# %%
# Add the Pandas dependency.
import pandas as pd

# %%
# Files to load
student_data_to_load = "Resources/students_complete.csv"

student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Read the school data file and store it in a Pandas DataFrame.
#school_data_df = pd.read_csv(school_data_to_load)
#school_data_df

# %%
# Read the student data file and store it in a Pandas DataFrame.
#student_data_df = pd.read_csv(student_data_to_load)
#student_data_df.head()

# %%
# Determine if there are any missing values in the school data.
#school_data_df.count()

# %%
# Determine if there are any missing values in the student data.
student_data_df.count()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# dtype: int64

# %%
# Determine if there are any missing values in the school data.
#school_data_df.isnull()

# %%
# Deteremine if there any missing values in the student data.
student_data_df.isnull()
# Out:
#        Student ID  student_name  gender  grade  school_name  reading_score  \
# 0           False         False   False  False        False          False
# 1           False         False   False  False        False          False
# 2           False         False   False  False        False          False
# 3           False         False   False  False        False          False
# 4           False         False   False  False        False          False
# ...           ...           ...     ...    ...          ...            ...
# 39165       False         False   False  False        False          False
# 39166       False         False   False  False        False          False
# 39167       False         False   False  False        False          False
# 39168       False         False   False  False        False          False
# 39169       False         False   False  False        False          False
#
#        math_score
# 0           False
# 1           False
# ...

# %%
# Determine if there are any missing values in the school data.
#school_data_df.isnull().sum()

# %%
# Determine if there are any missing values in the student data.
student_data_df.isnull().sum()
# Out:
# Student ID       0
# student_name     0
# gender           0
# grade            0
# school_name      0
# reading_score    0
# math_score       0
# dtype: int64

# %%
# Determine if there are not any missing values in the school data.
#school_data_df.notnull()

# %%
# Determine if there are not any missing values in the student data.
student_data_df.notnull()
# Out:
#        Student ID  student_name  gender  grade  school_name  reading_score  \
# 0            True          True    True   True         True           True
# 1            True          True    True   True         True           True
# 2            True          True    True   True         True           True
# 3            True          True    True   True         True           True
# 4            True          True    True   True         True           True
# ...           ...           ...     ...    ...          ...            ...
# 39165        True          True    True   True         True           True
# 39166        True          True    True   True         True           True
# 39167        True          True    True   True         True           True
# 39168        True          True    True   True         True           True
# 39169        True          True    True   True         True           True
#
#        math_score
# 0            True
# 1            True
# ...

# %%
# Determine if there are not any missing values in the school data.
#school_data_df.notnull().sum()

# %%
# Determine if there are not any missing values in the student data.
student_data_df.notnull().sum()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# dtype: int64

# %%
# Determine data types for the school DataFrame
#school_data_df.dtypes

# %%
# Determine data types for the student DataFrame.
#student_data_df.dtypes

# %%
# Put the student names in a list.
student_names = student_data_df["student_name"].tolist()
student_names
# Out:
# ['Paul Bradley',
#  'Victor Smith',
#  'Kevin Rodriguez',
#  'Dr. Richard Scott',
#  'Bonnie Ray',
#  'Bryan Miranda',
#  'Sheena Carter',
#  'Nicole Baker',
#  'Michael Roth',
#  'Matthew Greene',
#  'Andrew Alexander',
#  'Daniel Cooper',
#  'Brittney Walker',
#  'William Long',
#  'Tammy Hebert',
#  'Dr. Jordan Carson',
#  'Donald Zamora',
#  'Kimberly Santiago',
#  'Kevin Stevens',
#  'Brandi Lyons',
#  'Lisa Davis',
#  'Kristen Lopez',
#  'Kimberly Stewart',
#  'Christopher Parker',
#  'Chelsea Griffith',
#  'Cesar Morris',
#  'Melanie Decker',
#  'Tracey Oconnor',
#  'Kelly James',
#  'Nicole Brown',
#  'Bobby Harris',
#  'Brian Fernandez',
#  'Candace Phelps',
#  'Amy Gonzalez',
#  'Steven Green',
#  'Benjamin Carlson',
#  'Kevin Bailey',
#  'Jesse Newton',
#  'Kimberly Mercado',
#  'Gregory Roberts',
#  'Matthew Mayer',
#  'Jennifer Parks',
#  'John Carlson',
#  'Megan Roberts',
#  'Debra Flores',
#  'Heidi Jackson',
#  'Denise Bradford',
#  'Ellen Brown',
#  'Amy Perkins',
# ...

# %%
name = "Mrs. Linda Santiago"
name.split()
# Out:
# ['Mrs.', 'Linda', 'Santiago']

# %%
# Create a new list and use it for the for loop to iterate through the list.
students_to_fix = []

# Use an if statement to check the length of the name.
# If the name is greater than or equal to "3", add the name to the list.

#for name in student_names:
    #if len(name.split()) >=3:
        #students_to_fix.append(name)

# Get the length of the students whose names are greater than or equal to "3".
#len(students_to_fix)
#print(students_to_fix)

# %%
# Add the prefixes less than or equal to 4 to a new list.
#prefixes = []
#for name in students_to_fix:
    #if len(name.split()[0]) <= 4:
        #prefixes.append(name.split()[0])

#print(prefixes)

# %%
# Add the suffixes less than or equal to 3 to a new list.
#suffixes = []
#for name in students_to_fix:
    #if len(name.split()[-1]) <= 3:
        #suffixes.append(name.split()[-1])

#print(suffixes)

# %%
# Get the unique items in the "prefixes" list
set(prefixes)
# Out:
# {'Adam',
#  'Amy',
#  'Anna',
#  'Anne',
#  'Carl',
#  'Chad',
#  'Cody',
#  'Cory',
#  'Dale',
#  'Dana',
#  'Dawn',
#  'Dr.',
#  'Emma',
#  'Eric',
#  'Erik',
#  'Erin',
#  'Gail',
#  'Gary',
#  'Gina',
#  'Greg',
#  'Ian',
#  'Jill',
#  'Jodi',
#  'Joe',
#  'John',
#  'Jon',
#  'Jose',
#  'Judy',
#  'Kara',
#  'Kari',
#  'Kim',
#  'Kyle',
#  'Leah',
#  'Lisa',
#  'Lori',
#  'Luke',
#  'Lynn',
#  'Marc',
#  'Mark',
#  'Mary',
#  'Mike',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Ms.',
#  'Noah',
#  'Omar',
#  'Paul',
#  'Ruth',
#  'Ryan',
#  'Sara',
#  'Sean',
#  'Seth',
#  'Tara',
#  'Tina',
#  'Todd',
#  'Toni',
#  'Tony',
#  'Troy'}

# %%
# Get the unique items in the "suffixes" list
set(suffixes)
# Out:
# {'Cox',
#  'DDS',
#  'DVM',
#  'Day',
#  'II',
#  'III',
#  'IV',
#  'Jr.',
#  'Kim',
#  'Lee',
#  'Li',
#  'MD',
#  'PhD',
#  'Roy',
#  'V'}

# %%
# Strip "Mrs." from the student names
#for name in students_to_fix:
    #print(name.strip("Mrs."))

# %%
# Replace "Dr." with an empty string
#name = "Dr. Linda Santiago"
#name.replace("Dr. ", "")

# %%
# Add each prefix ad suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ", "Ms. ", "Mrs. ", "Miss. ", " MD", " DDS", " DVM", " phD"]

# %%
#word = prefixes_suffixes

# %%
#student_data_df["student_name"].str.replace("word","")

# %%
#student_data_df.head(50)

# %%
# Iterate through the "prefixes_suffixes" list and replace them with an empty string space, "" when it appears in the student's name. 
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
# Out:
# C:\Users\16699\AppData\Local\Temp/ipykernel_8160/3400768342.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")

# %%
student_data_df.head(220)
# Out:
#      Student ID     student_name gender grade        school_name  \
# 0             0     Paul Bradley      M   9th  Huang High School
# 1             1     Victor Smith      M  12th  Huang High School
# 2             2  Kevin Rodriguez      M  12th  Huang High School
# 3             3    Richard Scott      M  12th  Huang High School
# 4             4       Bonnie Ray      F   9th  Huang High School
# ..          ...              ...    ...   ...                ...
# 215         215     Ruben Rivera      M   9th  Huang High School
# 216         216   Patricia Petty      F  12th  Huang High School
# 217         217    Joseph Jacobs      M  11th  Huang High School
# 218         218    Bianca Wilson      F  11th  Huang High School
# 219         219     Donald Perez      M   9th  Huang High School
#
#      reading_score  math_score
# 0               66          79
# 1               94          61
# 2               90          60
# 3               67          58
# ...

# %%
# Put the cleaned students' names in another list.
student_names = student_data_df["student_name"].tolist()
student_names
# Out:
# ['Paul Bradley',
#  'Victor Smith',
#  'Kevin Rodriguez',
#  'Richard Scott',
#  'Bonnie Ray',
#  'Bryan Miranda',
#  'Sheena Carter',
#  'Nicole Baker',
#  'Michael Roth',
#  'Matthew Greene',
#  'Andrew Alexander',
#  'Daniel Cooper',
#  'Brittney Walker',
#  'William Long',
#  'Tammy Hebert',
#  'Jordan Carson',
#  'Donald Zamora',
#  'Kimberly Santiago',
#  'Kevin Stevens',
#  'Brandi Lyons',
#  'Lisa Davis',
#  'Kristen Lopez',
#  'Kimberly Stewart',
#  'Christopher Parker',
#  'Chelsea Griffith',
#  'Cesar Morris',
#  'Melanie Decker',
#  'Tracey Oconnor',
#  'Kelly James',
#  'Nicole Brown',
#  'Bobby Harris',
#  'Brian Fernandez',
#  'Candace Phelps',
#  'Amy Gonzalez',
#  'Steven Green',
#  'Benjamin Carlson',
#  'Kevin Bailey',
#  'Jesse Newton',
#  'Kimberly Mercado',
#  'Gregory Roberts',
#  'Matthew Mayer',
#  'Jennifer Parks',
#  'John Carlson',
#  'Megan Roberts',
#  'Debra Flores',
#  'Heidi Jackson',
#  'Denise Bradford',
#  'Ellen Brown',
#  'Amy Perkins',
# ...

# %%
# Create a new list and use it for the for loop iterate through the list.
students_fixed = []

# Use and if statement to check the length of the name.

# If the name is greater than or equal to 3, add the name to the list.

for name in student_names:
    if len(name.split()) >= 3:
        students_fixed.append(name)
        
# Get the length of the students' names that are greater than or equal to 3
len(students_fixed)
# Out:
# 268

# %%
#151

# %%
print(students_fixed)
# Out:
# ['Miss Madison Everett', 'Joseph Morales III', 'Xavier Bell II', 'Michael Moreno PhD', 'David Miller Jr.', 'Marcia Jones PhD', 'Reginald Garcia IV', 'Kevin Brown IV', 'William Washington Jr.', 'Darlene Thomas PhD', 'Juan Bryant II', 'Kenneth Paul Jr.', 'Scott Rivers III', 'Mark Myers Jr.', 'Miss Tara Banks', 'Miss Colleen Stewart', 'Todd Greene PhD', 'Michael Norton Jr.', 'Sean Pena Jr.', 'Miss Ebony Bell', 'Cody Mueller Jr.', 'Mathew White Jr.', 'Steven Snyder PhD', 'Jessica Warner PhD', 'Jason Daugherty Jr.', 'Leonard Webster II', 'David Taylor PhD', 'Terri Quinn PhD', 'Michael Stein Jr.', 'Alexandra Hood PhD', 'Ryan Phillips Jr.', 'Mario Wheeler PhD', 'Allen Snyder Jr.', 'Calvin Williams Jr.', 'Miss Jennifer Gibson', 'Miss Christy Robinson', 'Ronald Torres Jr.', 'Richard Williams PhD', 'Michael Baker PhD', 'Gabriel Smith III', 'Ronald Mayer PhD', 'Brian Pitts Jr.', 'Miss Kimberly Joseph', 'Bruce Thompson II', 'Jeremy Sanders II', 'Miss Amber Wallace', 'Jennifer Smith PhD', 'Austin
# ...
